# %%
#Imports
import os
import shutil
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from pathFunc import dbPath, dataDir

# %%
"""#Filters out the required excel files (makes a copy)
dataset_dir = "C:\\Users\\shash\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Data\\All Data"  # replace with the path to your dataset folder
filtered_dir = "C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2"  # replace with the path to the folder where you want to store the filtered data
if not os.path.exists(filtered_dir):
    os.makedirs(filtered_dir)

for month_folder in os.listdir(dataset_dir):
    if not month_folder.startswith("20"):  # skip any folders that don't start with a date
        continue
    for csv_file in os.listdir(os.path.join(dataset_dir, month_folder)):
        if not csv_file.endswith("-metropolitan-street.csv"):  # skip any files that don't match the desired format
            continue
        source_path = os.path.join(dataset_dir, month_folder, csv_file)
        destination_path = os.path.join(filtered_dir, csv_file)
        shutil.copy(source_path, destination_path)  # copy the matching file to the filtered_data folder"""
# Out:
# '#Filters out the required excel files (makes a copy)\ndataset_dir = "C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Data\\All Data"  # replace with the path to your dataset folder\nfiltered_dir = "C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2"  # replace with the path to the folder where you want to store the filtered data\nif not os.path.exists(filtered_dir):\n    os.makedirs(filtered_dir)\n\nfor month_folder in os.listdir(dataset_dir):\n    if not month_folder.startswith("20"):  # skip any folders that don\'t start with a date\n        continue\n    for csv_file in os.listdir(os.path.join(dataset_dir, month_folder)):\n        if not csv_file.endswith("-metropolitan-street.csv"):  # skip any files that don\'t match the desired format\n            continue\n        source_path = os.path.join(dataset_dir, month_folder, csv_file)\n        destination_path = os.path.join(filtered_dir, csv_file)\n        shutil.copy(source_path, destination_path)  # copy the matching file to the filtered_data folder'

# %%
"""conn = sqlite3.connect('C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Shared DC2 Group 19\\Cleaned Data\\database_conc_na.db')
query = "SELECT * FROM table_name"
df = pd.read_sql(query, conn)

conn.close()"""
# Out:
# 'conn = sqlite3.connect(\'C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Shared DC2 Group 19\\Cleaned Data\\database_conc_na.db\')\nquery = "SELECT * FROM table_name"\ndf = pd.read_sql(query, conn)\n\nconn.close()'

# %%
"""
folder_path = dataDir().joinpath('2023-04CLEANED')
df_list = []
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # only read in CSV files
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        df_list.append(df)
combined_df = pd.concat(df_list, ignore_index=True)
"""
# Out:
# '\nfolder_path = dataDir().joinpath(\'2023-04CLEANED\')\ndf_list = []\nfor file in os.listdir(folder_path):\n    if file.endswith(".csv"):  # only read in CSV files\n        file_path = os.path.join(folder_path, file)\n        df = pd.read_csv(file_path)\n        df_list.append(df)\ncombined_df = pd.concat(df_list, ignore_index=True)\n'

# %%
"""null_counts = combined_df.isnull().sum()
print(null_counts)"""
# Out:
# 'null_counts = combined_df.isnull().sum()\nprint(null_counts)'

# %%
"""output_path =dataDir().joinpath('combined_df_updated.csv')
combined_df.to_csv(output_path, index=False) # save the combined DataFrame to a new CSV file"""
# Out:
# "output_path =dataDir().joinpath('combined_df_updated.csv')\ncombined_df.to_csv(output_path, index=False) # save the combined DataFrame to a new CSV file"

# %%
"""combined_df
bar_burg = combined_df.loc[(combined_df['LSOA name'].str.contains('Barnet', case=False)) & (combined_df['Crime type'] == 'Burglary')]"""
# Out:
# "combined_df\nbar_burg = combined_df.loc[(combined_df['LSOA name'].str.contains('Barnet', case=False)) & (combined_df['Crime type'] == 'Burglary')]"

# %%
"""start_year = 2013 #what data you will process
end_year = 2022
train_lower, train_upper = 2014, 2018 #what data you give the model to train
test_lower, test_upper = 2019, 2019 #test years for model


df_bar=bar_burg[bar_burg['LSOA name'].str.contains('Barnet' or 'barnet')].drop(columns=['Reported by', 'Falls within'])
df_bar['Month'] = pd.to_datetime(df_bar['Month'])
df_bar['Year']= df_bar['Month'].dt.year
df_bar_5yr = df_bar[(df_bar['Month'].dt.year >= start_year) & (df_bar['Month'].dt.year <= end_year)]

#Filtering for Barnet data, 2013 included for time lag"""
# Out:
# "start_year = 2013 #what data you will process\nend_year = 2022\ntrain_lower, train_upper = 2014, 2018 #what data you give the model to train\ntest_lower, test_upper = 2019, 2019 #test years for model\n\n\ndf_bar=bar_burg[bar_burg['LSOA name'].str.contains('Barnet' or 'barnet')].drop(columns=['Reported by', 'Falls within'])\ndf_bar['Month'] = pd.to_datetime(df_bar['Month'])\ndf_bar['Year']= df_bar['Month'].dt.year\ndf_bar_5yr = df_bar[(df_bar['Month'].dt.year >= start_year) & (df_bar['Month'].dt.year <= end_year)]\n\n#Filtering for Barnet data, 2013 included for time lag"

# %%
lsoa_codes_bar = ['E01000115', 'E01000116', 'E01000117', 'E01000118', 'E01000119', 'E01000120', 'E01000121', 'E01000122', 'E01000123', 'E01000124', 'E01000125', 'E01000126', 'E01000127', 'E01000128', 'E01000129', 'E01000130', 'E01000131', 'E01000132', 'E01000133', 'E01000134', 'E01000135', 'E01000136', 'E01000137', 'E01000138', 'E01000139', 'E01000140', 'E01000141', 'E01000142', 'E01000143', 'E01000144', 'E01000145', 'E01000146', 'E01000147', 'E01000148', 'E01000150', 'E01000151', 'E01000152', 'E01000153', 'E01000154', 'E01000155', 'E01000156', 'E01000157', 'E01000158', 'E01000159', 'E01000160', 'E01000161', 'E01000162', 'E01000163', 'E01000164', 'E01000165', 'E01000166', 'E01000167', 'E01000168', 'E01000169', 'E01000170', 'E01000171', 'E01000172', 'E01000173', 'E01000174', 'E01000175', 'E01000176', 'E01000177', 'E01000178', 'E01000179', 'E01000180', 'E01000181', 'E01000182', 'E01000183', 'E01000184', 'E01000185', 'E01000186', 'E01000187', 'E01000188', 'E01000189', 'E01000190', 'E01000191', 'E01000192', 'E01000193', 'E01000194', 'E01000195', 'E01000196', 'E01000197', 'E01000198', 'E01000199', 'E01000200', 'E01000201', 'E01000202', 'E01000203', 'E01000204', 'E01000205', 'E01000206', 'E01000207', 'E01000208', 'E01000209', 'E01000210', 'E01000211', 'E01000212', 'E01000213', 'E01000214', 'E01000215', 'E01000216', 'E01000217', 'E01000218', 'E01000219', 'E01000220', 'E01000221', 'E01000222', 'E01000223', 'E01000224', 'E01000225', 'E01000226', 'E01000227', 'E01000228', 'E01000229', 'E01000230', 'E01000231', 'E01000232', 'E01000233', 'E01000234', 'E01000235', 'E01000236', 'E01000237', 'E01000238', 'E01000239', 'E01000240', 'E01000241', 'E01000242', 'E01000243', 'E01000244', 'E01000245', 'E01000246', 'E01000247', 'E01000248', 'E01000249', 'E01000250', 'E01000251', 'E01000252', 'E01000253', 'E01000254', 'E01000255', 'E01000256', 'E01000257', 'E01000258', 'E01000259', 'E01000260', 'E01000261', 'E01000262', 'E01000263', 'E01000264', 'E01000265', 'E01000266', 'E01000267', 'E01000268', 'E01000269', 'E01000270', 'E01000271', 'E01000272', 'E01000273', 'E01000274', 'E01000275', 'E01000276', 'E01000277', 'E01000278', 'E01000279', 'E01000280', 'E01000281', 'E01000282', 'E01000283', 'E01000284', 'E01000285', 'E01000286', 'E01000287', 'E01000288', 'E01000289', 'E01000290', 'E01000291', 'E01000292', 'E01000293', 'E01000294', 'E01000295', 'E01000296', 'E01000297', 'E01000298', 'E01000299', 'E01000300', 'E01000301', 'E01000302', 'E01000303', 'E01000304', 'E01000305', 'E01000306', 'E01000307', 'E01000308', 'E01000309', 'E01000310', 'E01000311', 'E01000312', 'E01000313', 'E01000314', 'E01000315', 'E01000316', 'E01000317', 'E01000318', 'E01000319', 'E01000320', 'E01000321', 'E01000322', 'E01000323', 'E01000324', 'E01033572', 'E01033573']

# %%
"""start_year = 2013 #what data you will process
end_year = 2022
train_lower, train_upper = 2014, 2018 #what data you give the model to train
test_lower, test_upper = 2019, 2019 #test years for model
df_bar=combined_df[combined_df['LSOA code'].isin(lsoa_codes_bar)].drop(columns=['Reported by', 'Falls within'])
df_bar['Month'] = pd.to_datetime(df_bar['Month'])
df_bar['Year']= df_bar['Month'].dt.year
df_bar_5yr = df_bar[(df_bar['Month'].dt.year >= start_year) & (df_bar['Month'].dt.year <= end_year)]
df_bar_5yr
#Filtering for Barnet data, 2013 included for time lag"""
# Out:
# "start_year = 2013 #what data you will process\nend_year = 2022\ntrain_lower, train_upper = 2014, 2018 #what data you give the model to train\ntest_lower, test_upper = 2019, 2019 #test years for model\ndf_bar=combined_df[combined_df['LSOA code'].isin(lsoa_codes_bar)].drop(columns=['Reported by', 'Falls within'])\ndf_bar['Month'] = pd.to_datetime(df_bar['Month'])\ndf_bar['Year']= df_bar['Month'].dt.year\ndf_bar_5yr = df_bar[(df_bar['Month'].dt.year >= start_year) & (df_bar['Month'].dt.year <= end_year)]\ndf_bar_5yr\n#Filtering for Barnet data, 2013 included for time lag"

# %%
"""unique_lsoas_per_month = df_bar_5yr.groupby('Month')['LSOA code'].nunique()

for lsoa in unique_lsoas_per_month:
    print(lsoa)"""
# Out:
# "unique_lsoas_per_month = df_bar_5yr.groupby('Month')['LSOA code'].nunique()\n\nfor lsoa in unique_lsoas_per_month:\n    print(lsoa)"

# %%
"""# Load CSV data into a pandas DataFrame
df = combined_df
# Connect to an SQLite database (creates a new database file if it doesn't exist)
conn = sqlite3.connect('C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Cleaned Data\\database_conc.db')
# Write DataFrame to an SQL database table
df.to_sql('table_name', conn, if_exists='replace', index=False)
# Close the database connection
conn.close()"""
# Out:
# "# Load CSV data into a pandas DataFrame\ndf = combined_df\n# Connect to an SQLite database (creates a new database file if it doesn't exist)\nconn = sqlite3.connect('C:\\Users\\shash\\OneDrive - TU Eindhoven\\Shashank Prabhu University\\Year 2\\Year 2 Q4\\Data Challenge 2\\Git DC2\\Cleaned Data\\database_conc.db')\n# Write DataFrame to an SQL database table\ndf.to_sql('table_name', conn, if_exists='replace', index=False)\n# Close the database connection\nconn.close()"

# %%
#Imports
import os
import shutil
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
from pathFunc import dbPath, dataDir
from pathlib import Path

import matplotlib.patches as mpatches

# %%
#__________________RUN FROM THIS CELL AND BELOW____________________

file_path =dataDir().joinpath('conc_clean.csv')
combined_df = pd.read_csv(file_path)

# %%
# Load the cleaned data into a dataframe
df = combined_df

# Filter the rows to only include burglaries
burglaries = df[df['Crime type'] == 'Burglary']

# Group the remaining rows by month and calculate the mean longitude and latitude
monthly_means = burglaries.groupby('Month')[['Longitude', 'Latitude']].mean()

# Reset the index to make the 'Month' column a regular column
monthly_means = monthly_means.reset_index()

# Plot the monthly means using seaborn's scatterplot function
sns.scatterplot(data=monthly_means, x='Longitude', y='Latitude')
# Out:
# <AxesSubplot: xlabel='Longitude', ylabel='Latitude'>

# %%
# Load the cleaned data into a dataframe
df = combined_df
lsoa_codes_bar = ['E01000115', 'E01000116', 'E01000117', 'E01000118', 'E01000119', 'E01000120', 'E01000121', 'E01000122', 'E01000123', 'E01000124', 'E01000125', 'E01000126', 'E01000127', 'E01000128', 'E01000129', 'E01000130', 'E01000131', 'E01000132', 'E01000133', 'E01000134', 'E01000135', 'E01000136', 'E01000137', 'E01000138', 'E01000139', 'E01000140', 'E01000141', 'E01000142', 'E01000143', 'E01000144', 'E01000145', 'E01000146', 'E01000147', 'E01000148', 'E01000150', 'E01000151', 'E01000152', 'E01000153', 'E01000154', 'E01000155', 'E01000156', 'E01000157', 'E01000158', 'E01000159', 'E01000160', 'E01000161', 'E01000162', 'E01000163', 'E01000164', 'E01000165', 'E01000166', 'E01000167', 'E01000168', 'E01000169', 'E01000170', 'E01000171', 'E01000172', 'E01000173', 'E01000174', 'E01000175', 'E01000176', 'E01000177', 'E01000178', 'E01000179', 'E01000180', 'E01000181', 'E01000182', 'E01000183', 'E01000184', 'E01000185', 'E01000186', 'E01000187', 'E01000188', 'E01000189', 'E01000190', 'E01000191', 'E01000192', 'E01000193', 'E01000194', 'E01000195', 'E01000196', 'E01000197', 'E01000198', 'E01000199', 'E01000200', 'E01000201', 'E01000202', 'E01000203', 'E01000204', 'E01000205', 'E01000206', 'E01000207', 'E01000208', 'E01000209', 'E01000210', 'E01000211', 'E01000212', 'E01000213', 'E01000214', 'E01000215', 'E01000216', 'E01000217', 'E01000218', 'E01000219', 'E01000220', 'E01000221', 'E01000222', 'E01000223', 'E01000224', 'E01000225', 'E01000226', 'E01000227', 'E01000228', 'E01000229', 'E01000230', 'E01000231', 'E01000232', 'E01000233', 'E01000234', 'E01000235', 'E01000236', 'E01000237', 'E01000238', 'E01000239', 'E01000240', 'E01000241', 'E01000242', 'E01000243', 'E01000244', 'E01000245', 'E01000246', 'E01000247', 'E01000248', 'E01000249', 'E01000250', 'E01000251', 'E01000252', 'E01000253', 'E01000254', 'E01000255', 'E01000256', 'E01000257', 'E01000258', 'E01000259', 'E01000260', 'E01000261', 'E01000262', 'E01000263', 'E01000264', 'E01000265', 'E01000266', 'E01000267', 'E01000268', 'E01000269', 'E01000270', 'E01000271', 'E01000272', 'E01000273', 'E01000274', 'E01000275', 'E01000276', 'E01000277', 'E01000278', 'E01000279', 'E01000280', 'E01000281', 'E01000282', 'E01000283', 'E01000284', 'E01000285', 'E01000286', 'E01000287', 'E01000288', 'E01000289', 'E01000290', 'E01000291', 'E01000292', 'E01000293', 'E01000294', 'E01000295', 'E01000296', 'E01000297', 'E01000298', 'E01000299', 'E01000300', 'E01000301', 'E01000302', 'E01000303', 'E01000304', 'E01000305', 'E01000306', 'E01000307', 'E01000308', 'E01000309', 'E01000310', 'E01000311', 'E01000312', 'E01000313', 'E01000314', 'E01000315', 'E01000316', 'E01000317', 'E01000318', 'E01000319', 'E01000320', 'E01000321', 'E01000322', 'E01000323', 'E01000324', 'E01033572', 'E01033573']

# Convert the 'Month' column to a pandas datetime object
df['Month'] = pd.to_datetime(df['Month'])

# Filter the dataframe to only include rows with 'Burglary' in the 'Crime type' column
burglary_df_all = df[df['Crime type'] == 'Burglary'] 

burglary_df = burglary_df_all[burglary_df_all['LSOA code'].isin(lsoa_codes_bar)]
# Create a new dataframe with every month of all years
all_months = pd.DataFrame(pd.date_range(start='2010-12-01', end='2023-01-01', freq='MS'), columns=['Month'])

# Group the 'Burglary' dataframe by month and count the number of rows in each month
monthly_counts = burglary_df.groupby(pd.Grouper(key='Month', freq='MS'))['Crime type'].count()

# Combine the 'all_months' dataframe and the 'monthly_counts' series
combined_df_copy = pd.merge(all_months, pd.DataFrame(monthly_counts), how='left', left_on='Month', right_on='Month')

# Fill any missing values with 0
combined_df_copy.fillna(0, inplace=True)

# Rename the 'Crime type' column to 'Number of Burglaries'
combined_df_copy.rename(columns={'Crime type': 'Number of Burglaries'}, inplace=True)

# Set the 'Month' column as the index
combined_df_copy.set_index('Month', inplace=True)
combined_df_copy = combined_df_copy.reset_index()

# Preview the resulting dataframe
combined_df_copy.head()
# Out:
#        Month  Number of Burglaries
# 0 2010-12-01                   372
# 1 2011-01-01                   486
# 2 2011-02-01                   403
# 3 2011-03-01                   408
# 4 2011-04-01                   414

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(15, 5))
ax = sns.lineplot(data=combined_df_copy, x='Month', y='Number of Burglaries', marker='o', c='r')
# Customize the x-axis ticks to show every year
#plt.xticks(ticks=combined_df_copy.index, labels=combined_df_copy.index.strftime("%Y"), rotation=45, ha="right")

# Add axis labels and a title
plt.xlabel('Year')
plt.ylabel('Number of Burglaries')
plt.title('Monthly Burglary Counts from 2010 to 2023')

plt.show()

# %%
# Create a new figure and axis
fig, ax = plt.subplots(figsize=(15, 8))

# Plot the data
sns.lineplot(data=combined_df_copy, x='Month', y='Number of Burglaries', ax=ax, color='black', linewidth='2', marker='o')

# Define the seasons and their corresponding colors
seasons = {
    'Spring': ('03-01', '05-31', 'green'),
    'Summer': ('06-01', '08-31', 'orange'),
    'Fall': ('09-01', '11-30', 'red'),
    'Winter': ('12-01', '02-28', 'blue')
}

# Add the seasonal background colors
for year in range(2010, 2023):
    for season, (start, end, color) in seasons.items():
        if season == 'Winter':
            ax.axvspan(pd.Timestamp(f'{year}-{start}'), pd.Timestamp(f'{year + 1}-{end}'),
                       alpha=0.21, color=color)
        else:
            ax.axvspan(pd.Timestamp(f'{year}-{start}'), pd.Timestamp(f'{year}-{end}'),
                       alpha=0.21, color=color)

ax.set_xlim(pd.Timestamp('2010-09-01'), pd.Timestamp('2023-02-01'))

# Create legend patches for each season
legend_patches = [mpatches.Patch(color=color, label=season, alpha=0.5) for season, (_, _, color) in seasons.items()]

# Add legend to the plot
ax.legend(handles=legend_patches, loc='upper right', bbox_to_anchor=(0.98, 0.95), prop={'size': 17})

# Set the plot title and axis labels
plt.title('Number of Burglaries by Month in Barnet', fontsize=17)
plt.xlabel('Year (Seasons color encoded)', fontsize=13)
plt.ylabel('Number of Burglaries', fontsize=13)

# Show the plot
plt.show()

# %%
# Group the dataframe by Crime type
crime_type_groups = combined_df.groupby('Crime type')

# Create separate dataframes for each crime type
crime_type_dfs = {}
for crime_type, group in crime_type_groups:
    crime_type_dfs[crime_type] = group.copy()

# %%
count_dict = {}
pivot_dict = {}

for crime_type, df in crime_type_dfs.items():
    count_df = df.groupby(['Month', 'Crime type']).size().reset_index(name='Count')
    pivot_df = count_df.pivot_table(values='Count', index='Month', columns='Crime type')
    
    count_dict[crime_type] = count_df
    pivot_dict[crime_type] = pivot_df

# %%
for key, value in pivot_dict.items():
    print(key)
# Out:
# Anti-social behaviour
# Bicycle theft
# Burglary
# Criminal damage and arson
# Drugs
# Other crime
# Other theft
# Possession of weapons
# Public disorder and weapons
# Public order
# Robbery
# Shoplifting
# Theft from the person
# Vehicle crime
# Violence and sexual offences
# Violent crime

# %%
import matplotlib.pyplot as plt

# create a new figure
fig, ax = plt.subplots(figsize=(10, 6))

# iterate over the dataframes in pivot_dict and plot each one
for crime_type, df in pivot_dict.items():
    ax.plot(df.index, df.values, label=crime_type)

# set the x-axis label
ax.set_xlabel('Month')

# set the y-axis label
ax.set_ylabel('Count')

# set the plot title
ax.set_title('Crime counts by month')

# add a legend
ax.legend(fontsize=6)

# show the plot
plt.show()

# %%
# Create a new DataFrame with only the necessary columns
crime_type_df = combined_df[['Crime type', 'Month', 'Longitude', 'Latitude']]

# Pivot the DataFrame to get the counts of each crime type per month
pivot_df = crime_type_df.pivot_table(index='Month', columns='Crime type', aggfunc='size', fill_value=0)

# Create the scatterplot matrix
sns.pairplot(pivot_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 8
#       5 pivot_df = crime_type_df.pivot_table(index='Month', columns='Crime type', aggfunc='size', fill_value=0)
#       7 # Create the scatterplot matrix
# ----> 8 sns.pairplot(pivot_df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:2174, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2171 if hue is not None:
#    2172     grid.add_legend()
# -> 2174 grid.tight_layout()
#    2176 return grid
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\figure.py:3445, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3443 try:
#    3444     self.set_layout_engine(engine)
# -> 3445     engine.execute(self)
#    3446 finally:
#    3447     self.set_layout_engine(None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\layout_engine.py:180, in TightLayoutEngine.execute(self, fig)
#     178 renderer = fig._get_renderer()
#     179 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 180     kwargs = get_tight_layout_figure(
#     181         fig, fig.axes, subplotspec_list, renderer,
#     182         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     183         rect=info['rect'])
#     184 if kwargs:
#     185     fig.subplots_adjust(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\_tight_layout.py:332, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     329     if top is not None:
#     330         top -= (1 - kwargs["top"])
# --> 332     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     333                                       shape=(max_nrows, max_ncols),
#     334                                       span_pairs=span_pairs,
#     335                                       subplot_list=subplot_list,
#     336                                       ax_bbox_list=ax_bbox_list,
#     337                                       pad=pad, h_pad=h_pad, w_pad=w_pad,
#     338                                       rect=(left, bottom, right, top))
#     340 return kwargs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:1378, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1372 """
#    1373 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1374 *for_layout_only* kwarg; this helper tries to uses the kwarg but skips it
#    1375 when encountering third-party subclasses that do not support it.
#    1376 """
#    1377 try:
# -> 1378     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1379 except TypeError:
#    1380     return obj.get_tightbbox(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:4431, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4429         if ba:
#    4430             bb.append(ba)
# -> 4431 self._update_title_position(renderer)
#    4432 axbbox = self.get_window_extent(renderer)
#    4433 bb.append(axbbox)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:3006, in _AxesBase._update_title_position(self, renderer)
#    3003 bb = None
#    3004 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    3005         or ax.xaxis.get_label_position() == 'top'):
# -> 3006     bb = ax.xaxis.get_tightbbox(renderer)
#    3007 if bb is None:
#    3008     if 'outline' in ax.spines:
#    3009         # Special case for colorbars:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1251, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1249 if renderer is None:
#    1250     renderer = self.figure._get_renderer()
# -> 1251 ticks_to_draw = self._update_ticks()
#    1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1198, in Axis._update_ticks(self)
#    1196     tick.set_label1(label)
#    1197     tick.set_label2(label)
# -> 1198 minor_locs = self.get_minorticklocs()
#    1199 minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1200 minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1423, in Axis.get_minorticklocs(self)
#    1421 minor_locs = np.asarray(self.minor.locator())
#    1422 if self.remove_overlapping_locs:
# -> 1423     major_locs = self.major.locator()
#    1424     transform = self._scale.get_transform()
#    1425     tr_minor_locs = transform.transform(minor_locs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2143, in MaxNLocator.__call__(self)
#    2141 def __call__(self):
#    2142     vmin, vmax = self.axis.get_view_interval()
# -> 2143     return self.tick_values(vmin, vmax)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2151, in MaxNLocator.tick_values(self, vmin, vmax)
#    2148     vmin = -vmax
#    2149 vmin, vmax = mtransforms.nonsingular(
#    2150     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2151 locs = self._raw_ticks(vmin, vmax)
#    2153 prune = self._prune
#    2154 if prune == 'lower':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2090, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2088 if self._nbins == 'auto':
#    2089     if self.axis is not None:
# -> 2090         nbins = np.clip(self.axis.get_tick_space(),
#    2091                         max(1, self._min_n_ticks - 1), 9)
#    2092     else:
#    2093         nbins = 9
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:2423, in XAxis.get_tick_space(self)
#    2422 def get_tick_space(self):
# -> 2423     ends = mtransforms.Bbox.unit().transformed(
#    2424         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2425     length = ends.width * 72
#    2426     # There is a heuristic here that the aspect ratio of tick text
#    2427     # is no more than 3:1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2420, in CompositeGenericTransform.transform_affine(self, points)
#    2418 def transform_affine(self, points):
#    2419     # docstring inherited
# -> 2420     return self.get_affine().transform(points)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x00000139788DFF40> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:3071, in _AxesBase.draw(self, renderer)
#    3068     for spine in self.spines.values():
#    3069         artists.remove(spine)
# -> 3071 self._update_title_position(renderer)
#    3073 if not self.axison:
#    3074     for _axis in self._axis_map.values():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:3006, in _AxesBase._update_title_position(self, renderer)
#    3003 bb = None
#    3004 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    3005         or ax.xaxis.get_label_position() == 'top'):
# -> 3006     bb = ax.xaxis.get_tightbbox(renderer)
#    3007 if bb is None:
#    3008     if 'outline' in ax.spines:
#    3009         # Special case for colorbars:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1251, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1249 if renderer is None:
#    1250     renderer = self.figure._get_renderer()
# -> 1251 ticks_to_draw = self._update_ticks()
#    1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1190, in Axis._update_ticks(self)
#    1185 def _update_ticks(self):
#    1186     """
#    1187     Update ticks (position and labels) using the current data interval of
#    1188     the axes.  Return the list of ticks that will be drawn.
#    1189     """
# -> 1190     major_locs = self.get_majorticklocs()
#    1191     major_labels = self.major.formatter.format_ticks(major_locs)
#    1192     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:1416, in Axis.get_majorticklocs(self)
#    1414 def get_majorticklocs(self):
#    1415     """Return this Axis' major tick locations in data coordinates."""
# -> 1416     return self.major.locator()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2143, in MaxNLocator.__call__(self)
#    2141 def __call__(self):
#    2142     vmin, vmax = self.axis.get_view_interval()
# -> 2143     return self.tick_values(vmin, vmax)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2151, in MaxNLocator.tick_values(self, vmin, vmax)
#    2148     vmin = -vmax
#    2149 vmin, vmax = mtransforms.nonsingular(
#    2150     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2151 locs = self._raw_ticks(vmin, vmax)
#    2153 prune = self._prune
#    2154 if prune == 'lower':
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\ticker.py:2090, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2088 if self._nbins == 'auto':
#    2089     if self.axis is not None:
# -> 2090         nbins = np.clip(self.axis.get_tick_space(),
#    2091                         max(1, self._min_n_ticks - 1), 9)
#    2092     else:
#    2093         nbins = 9
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axis.py:2423, in XAxis.get_tick_space(self)
#    2422 def get_tick_space(self):
# -> 2423     ends = mtransforms.Bbox.unit().transformed(
#    2424         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2425     length = ends.width * 72
#    2426     # There is a heuristic here that the aspect ratio of tick text
#    2427     # is no more than 3:1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:479, in BboxBase.transformed(self, transform)
#     475 """
#     476 Construct a `Bbox` by statically transforming this one by *transform*.
#     477 """
#     478 pts = self.get_points()
# --> 479 ll, ul, lr = transform.transform(np.array(
#     480     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     481 return Bbox([ll, [lr[0], ul[1]]])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:1490, in Transform.transform(self, values)
#    1487 values = values.reshape((-1, self.input_dims))
#    1489 # Transform the values
# -> 1490 res = self.transform_affine(self.transform_non_affine(values))
#    1492 # Convert the result back to the shape of the input values.
#    1493 if ndim == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2420, in CompositeGenericTransform.transform_affine(self, points)
#    2418 def transform_affine(self, points):
#    2419     # docstring inherited
# -> 2420     return self.get_affine().transform(points)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
