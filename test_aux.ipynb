# %%
#Imports
import os
import shutil
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weather_df = pd.read_excel('Data\Weather\Daylight.xlsx', sheet_name=['Data'])['Data']
weather_df
# Out:
#      Calendar period  20-year mean \n[note 5]      2001      2002      2003  \
# 0            January                 1.835249  2.448102  1.495515  2.323001
# 1           February                 2.844714  3.125319  2.925442  3.623941
# 2              March                 4.073554  2.953300  3.804281  5.454046
# 3              April                 6.062081  4.744445  6.616119  6.728073
# 4                May                 6.556216  7.725524  6.155149  6.390996
# 5               June                 6.531307  6.845211  5.760137  7.193123
# 6               July                 6.442307  6.388091  5.700613  5.890142
# 7             August                 5.705159  5.905760  5.506359  6.977437
# 8          September                 5.003316  4.048802  5.432157  6.064175
# 9            October                 3.265707  3.582636  3.060449  4.348424
# 10          November                 2.261479  2.380912  1.974578  2.344859
# ...

# %%
holidays_df = pd.read_csv('Data\Holidays\Holidays.csv')
holidays_df
# Out:
#    Month_name  Month  Holidays
# 0     January      1         2
# 1    February      2         4
# 2       March      3         0
# 3       April      4        11
# 4         May      5         3
# 5        June      6         2
# 6        July      7         8
# 7      August      8        31
# 8   September      9         1
# 9     October     10         5
# 10   November     11         0
# 11   December     12        13
